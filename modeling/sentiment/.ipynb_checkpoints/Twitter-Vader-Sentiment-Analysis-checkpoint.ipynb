# %%
# pip install --upgrade ipykernel

# %%
# import pickle5 as pickle
# import carmen
# from pyarrow import json
# import jsonlines
# import json_lines
# from json2parquet import convert_json
# import csv
# import ijson
# import matplotlib
# import matplotlib.pyplot as plt
# import folium
# import os
# import numpy as np
# from matplotlib.colors import LinearSegmentedColormap
# import pyarrow.parquet as pq
# from sklearn.model_selection import train_test_split
# from sklearn.ensemble import RandomForestClassifier
# import pandas as pd
# from sklearn.preprocessing import StandardScaler

# %%
import pandas as pd
import numpy as np
from sklearn.preprocessing import StandardScaler
from matplotlib import*
import matplotlib.pyplot as plt
from matplotlib.cm import register_cmap
from scipy import stats
from sklearn.decomposition import PCA as sklearnPCA
import seaborn

# %%
import spacy
import re
from pprint import pprint
import nltk
nltk.download('vader_lexicon')
from nltk.sentiment.vader import SentimentIntensityAnalyzer
from nltk.corpus import stopwords
from collections import Counter
from wordcloud import WordCloud
import warnings 
warnings.filterwarnings("ignore", category=DeprecationWarning)
# %matplotlib inline
# Out:
# [nltk_data] Downloading package vader_lexicon to
# [nltk_data]     /Users/austingerner/nltk_data...
# [nltk_data]   Package vader_lexicon is already up-to-date!

# %%
# pd.set_option('display.max_rows', None)
# pd.set_option('display.max_columns', None)
# pd.set_option('display.width', None)
# pd.set_option('display.max_colwidth', -1)

# %% [markdown]
# # PCA Methods

# %% [markdown]
# # Import Data from XML - Convert into Dataframe

# %%
import pandas as pd 
import xml.etree.ElementTree as et 

xtree = et.parse("/Users/austingerner/Documents/gw/research/covid/code/diagnostics_75_topics.xml")
xroot = xtree.getroot()

# %%
df_cols = ["id", "tokens", "document_entropy", "avg-word-length", "avg-coherence", "uniform_dist", "corpus_dist", "token-doc-diff",
          "rank_1_docs", "allocation_ratio", "word_rank", "word_count", "word_prob","word_cumulative", "word_docs", "word-length", "word_coherence",
           "word_uniform_dist", "word_corpus_dist", "word-token-doc-diff", "word_exclusivity"]
rows = []

for node in xroot: 
    topic_id = node.attrib.get("id")
    topic_tokens = node.attrib.get("tokens")
    topic_entropy = node.attrib.get("document_entropy")
    topic_word_length = node.attrib.get("word-length")
    topic_coherence = node.attrib.get("coherence")
    topic_uniform_dist = node.attrib.get("uniform_dist")
    topic_corpus_dist = node.attrib.get("corpus_dist")
    topic_eff_num_words = node.attrib.get("token-doc-diff")
    topic_rank_1_docs = node.attrib.get("rank_1_docs")
    topic_allocation_ratio = node.attrib.get("allocation_ratio")
    
    rows.append({"id": topic_id, "tokens": topic_tokens, "document_entropy": topic_entropy, "avg-word-length": topic_word_length,
             "avg-coherence": topic_coherence, "uniform_dist": topic_uniform_dist, "corpus_dist": topic_corpus_dist, "token-doc-diff": topic_eff_num_words,
             "rank_1_docs": topic_rank_1_docs, "allocation_ratio": topic_allocation_ratio})

    for word in node.iter("word"):
        word_rank = word.attrib.get('rank')
        word_count = word.attrib.get('count')
        word_prob = word.attrib.get('prob')
        word_cumulative = word.attrib.get('cumulative')
        word_docs = word.attrib.get('docs')
        word_word_length = word.attrib.get('word-length')
        word_coherence = word.attrib.get('coherence')
        word_uniform_dist = word.attrib.get('uniform_dist')
        word_corpus_dist = word.attrib.get('corpus_dist')
        word_eff_num_words = word.attrib.get('token-doc-diff')
        word_exclusivity = word.attrib.get('exclusivity')
        rows.append({"id": topic_id, "word_rank": word_rank, "word_count": word_count,
                "word_prob": word_prob, "word_cumulative": word_cumulative, "word_docs": word_docs, "word-length": word_word_length, "word_coherence": word_coherence, 
                "word_uniform_dist": word_uniform_dist, "word_corpus_dist": word_corpus_dist, "word-token-doc-diff": word_eff_num_words, "word_exclusivity": word_exclusivity})
    
#         print("i")
    
tm_results_diagnostics_df = pd.DataFrame(rows, columns = df_cols)

# %%
tm_results_diagnostics_topic_detail.head(20)
# Out:
#    id word_rank word_count word_prob word_cumulative word_docs word-length  \
# 0   0         1      62216   0.15965         0.15965     60784     11.0000
# 1   0         2      29506   0.07571         0.23536     28657      5.0000
# 2   0         3      19033   0.04884         0.28420     18955      8.0000
# 3   0         4      14782   0.03793         0.32213     14635      9.0000
# 4   0         5      10734   0.02754         0.34967     10651      4.0000
# 5   0         6       9585   0.02460         0.37427      9383      4.0000
# 6   0         7       7688   0.01973         0.39399      7328      5.0000
# 7   0         8       7079   0.01816         0.41216      7057     11.0000
# 8   0         9       6837   0.01754         0.42970      6837     13.0000
# 9   0        10       6320   0.01622         0.44592      6212      4.0000
# 10  0        11       5927   0.01521         0.46113      5784      8.0000
# ...

# %%
tm_results_diagnostics_topic_overall = tm_results_diagnostics_df.copy()
tm_results_diagnostics_topic_detail = tm_results_diagnostics_df.copy()

# %%
tm_results_diagnostics_topic_overall = tm_results_diagnostics_topic_overall.drop(columns=["word_rank", "word_count", "word_prob","word_cumulative", "word_docs", "word-length", "word_coherence",
           "word_uniform_dist", "word_corpus_dist", "word-token-doc-diff", "word_exclusivity"])
tm_results_diagnostics_topic_overall = tm_results_diagnostics_topic_overall.dropna().reset_index()
tm_results_diagnostics_topic_overall.head()
tm_results_diagnostics_topic_overall = tm_results_diagnostics_topic_overall.drop(columns='index')

# %%
tm_results_diagnostics_topic_detail = tm_results_diagnostics_topic_detail.drop(columns=["tokens", "document_entropy", "avg-word-length", "avg-coherence", "uniform_dist", "corpus_dist", "token-doc-diff",
          "rank_1_docs", "allocation_ratio"])
tm_results_diagnostics_topic_detail = tm_results_diagnostics_topic_detail.dropna().reset_index()
tm_results_diagnostics_topic_detail = tm_results_diagnostics_topic_detail.drop(columns='index')

# %% [markdown]
# # PCA Analysis Overall Topic Diagnostic Data

# %%
x = tm_results_diagnostics_topic_overall.drop(labels='id', axis=1).values
y = tm_results_diagnostics_topic_overall['id']
X_std = StandardScaler().fit_transform(x)

# %%
mean_vec = np.mean(X_std, axis=0)
cov_mat = (X_std - mean_vec).T.dot((X_std - mean_vec)) / (X_std.shape[0]-1)
print('Covariance matrix \n%s' %cov_mat)
# Out:
# Covariance matrix
# [[ 1.01351351  0.37679794  0.23866241  0.21998956  0.1656666  -0.20640603
#    0.3951706   0.58324192  0.47331249]
#  [ 0.37679794  1.01351351  0.04056513  0.16606349 -0.0236241  -0.62066774
#   -0.24671135 -0.14620713 -0.51252838]
#  [ 0.23866241  0.04056513  1.01351351 -0.41858288  0.38805681 -0.24461645
#    0.30636751  0.19953287  0.2733027 ]
#  [ 0.21998956  0.16606349 -0.41858288  1.01351351 -0.40919541 -0.08558445
#   -0.47598192  0.14109919 -0.26190844]
#  [ 0.1656666  -0.0236241   0.38805681 -0.40919541  1.01351351 -0.18920336
#    0.6099032  -0.07451998  0.49409439]
#  [-0.20640603 -0.62066774 -0.24461645 -0.08558445 -0.18920336  1.01351351
#    0.09374907  0.27827046  0.30183805]
#  [ 0.3951706  -0.24671135  0.30636751 -0.47598192  0.6099032   0.09374907
#    1.01351351  0.28985699  0.75444099]
#  [ 0.58324192 -0.14620713  0.19953287  0.14109919 -0.07451998  0.27827046
#    0.28985699  1.01351351  0.5275297 ]
# ...

# %%
#Perform eigendecomposition on covariance matrix
cov_mat = np.cov(X_std.T)
eig_vals, eig_vecs = np.linalg.eig(cov_mat)
print('Eigenvectors \n%s' %eig_vecs)
print('\nEigenvalues \n%s' %eig_vals)
# Out:
# Eigenvectors
# [[-0.26628789 -0.37464651 -0.48532292  0.09990791 -0.53317537 -0.16351917
#   -0.25647517  0.40793703  0.00204823]
#  [ 0.20037893 -0.58922756 -0.07925098  0.02829991  0.51370454 -0.48217804
#    0.03486602 -0.00985205 -0.3284461 ]
#  [-0.29066362 -0.28755316  0.18195261 -0.71371517  0.08933463  0.35762639
#    0.18650567  0.31552644 -0.14182077]
#  [ 0.26859953 -0.03727384 -0.5240222   0.28946788  0.19004727  0.5869136
#    0.37204279  0.16508091 -0.14771918]
#  [-0.36169698 -0.21265144  0.33178734  0.40289484 -0.19983641  0.27025463
#   -0.02924377 -0.30363849 -0.5878128 ]
#  [-0.10776964  0.60160956 -0.12894899 -0.08618275  0.02696679 -0.3147051
#    0.11392475  0.33367404 -0.61507123]
#  [-0.49427184 -0.03097891  0.08112263  0.28065203  0.07406404 -0.25597643
#    0.69571058  0.10666796  0.32091825]
#  [-0.28653666  0.04922132 -0.54647536 -0.34400325 -0.01995573 -0.0685032
#    0.11120561 -0.69105806 -0.0590051 ]
# ...

# %%
# Visually confirm that the list is correctly sorted by decreasing eigenvalues
eig_pairs = [(np.abs(eig_vals[i]), eig_vecs[:,i]) for i in range(len(eig_vals))]
print('Eigenvalues in descending order:')
for i in eig_pairs:
    print(i[0])
# Out:
# Eigenvalues in descending order:
# 3.1835023358855916
# 2.02399248979253
# 1.7784987919564121
# 0.8099543468612139
# 0.03802934838937859
# 0.5372273315594727
# 0.1773424918053207
# 0.2394921137394279
# 0.3335823716322763

# %%
X_train, X_test, y_train, y_test = train_test_split(x, y, test_size=0.2, random_state=0)

# %%
sc = StandardScaler()
X_train = sc.fit_transform(X_train)
X_test = sc.transform(X_test)

# %%
pca = convers_pca(no_of_components=9)
pca.fit(X_train)

# %%
pca = PCA()
X_train = pca.fit_transform(X_train)
X_test = pca.transform(X_test)

# %%
explained_variance = pca.explained_variance_ratio_
explained_variance
# Out:
# array([0.35787757, 0.22256315, 0.19126936, 0.0898222 , 0.05667681,
#        0.03490719, 0.02799674, 0.01503188, 0.0038551 ])

# %% [markdown]
# # PCA Analysis Detail Topic Diagnostic Data

# %%
x_word = tm_results_diagnostics_topic_detail.drop(labels='id', axis=1).values
y_word = tm_results_diagnostics_topic_detail['id']
X_std = StandardScaler().fit_transform(x)
X_train, X_test, y_train, y_test = train_test_split(x_word, y_word, test_size=.4, random_state=0)

# %%
mean_vec = np.mean(X_std, axis=0)
cov_mat = (X_std - mean_vec).T.dot((X_std - mean_vec)) / (X_std.shape[0]-1)
print('Covariance matrix \n%s' %cov_mat)
# Out:
# Covariance matrix
# [[ 1.01351351  0.37679794  0.23866241  0.21998956  0.1656666  -0.20640603
#    0.3951706   0.58324192  0.47331249]
#  [ 0.37679794  1.01351351  0.04056513  0.16606349 -0.0236241  -0.62066774
#   -0.24671135 -0.14620713 -0.51252838]
#  [ 0.23866241  0.04056513  1.01351351 -0.41858288  0.38805681 -0.24461645
#    0.30636751  0.19953287  0.2733027 ]
#  [ 0.21998956  0.16606349 -0.41858288  1.01351351 -0.40919541 -0.08558445
#   -0.47598192  0.14109919 -0.26190844]
#  [ 0.1656666  -0.0236241   0.38805681 -0.40919541  1.01351351 -0.18920336
#    0.6099032  -0.07451998  0.49409439]
#  [-0.20640603 -0.62066774 -0.24461645 -0.08558445 -0.18920336  1.01351351
#    0.09374907  0.27827046  0.30183805]
#  [ 0.3951706  -0.24671135  0.30636751 -0.47598192  0.6099032   0.09374907
#    1.01351351  0.28985699  0.75444099]
#  [ 0.58324192 -0.14620713  0.19953287  0.14109919 -0.07451998  0.27827046
#    0.28985699  1.01351351  0.5275297 ]
# ...

# %%
#Perform eigendecomposition on covariance matrix
cov_mat = np.cov(X_std.T)
eig_vals, eig_vecs = np.linalg.eig(cov_mat)
print('Eigenvectors \n%s' %eig_vecs)
print('\nEigenvalues \n%s' %eig_vals)
# Out:
# Eigenvectors
# [[-0.26628789 -0.37464651 -0.48532292  0.09990791 -0.53317537 -0.16351917
#   -0.25647517  0.40793703  0.00204823]
#  [ 0.20037893 -0.58922756 -0.07925098  0.02829991  0.51370454 -0.48217804
#    0.03486602 -0.00985205 -0.3284461 ]
#  [-0.29066362 -0.28755316  0.18195261 -0.71371517  0.08933463  0.35762639
#    0.18650567  0.31552644 -0.14182077]
#  [ 0.26859953 -0.03727384 -0.5240222   0.28946788  0.19004727  0.5869136
#    0.37204279  0.16508091 -0.14771918]
#  [-0.36169698 -0.21265144  0.33178734  0.40289484 -0.19983641  0.27025463
#   -0.02924377 -0.30363849 -0.5878128 ]
#  [-0.10776964  0.60160956 -0.12894899 -0.08618275  0.02696679 -0.3147051
#    0.11392475  0.33367404 -0.61507123]
#  [-0.49427184 -0.03097891  0.08112263  0.28065203  0.07406404 -0.25597643
#    0.69571058  0.10666796  0.32091825]
#  [-0.28653666  0.04922132 -0.54647536 -0.34400325 -0.01995573 -0.0685032
#    0.11120561 -0.69105806 -0.0590051 ]
# ...

# %%
# Visually confirm that the list is correctly sorted by decreasing eigenvalues
eig_pairs = [(np.abs(eig_vals[i]), eig_vecs[:,i]) for i in range(len(eig_vals))]
print('Eigenvalues in descending order:')
for i in eig_pairs:
    print(i[0])
# Out:
# Eigenvalues in descending order:
# 3.1835023358855916
# 2.02399248979253
# 1.7784987919564121
# 0.8099543468612139
# 0.03802934838937859
# 0.5372273315594727
# 0.1773424918053207
# 0.2394921137394279
# 0.3335823716322763

# %%
sc = StandardScaler()
X_train = sc.fit_transform(X_train)
X_test = sc.transform(X_test)

# %%
pca = convers_pca(no_of_components=9)
pca.fit(X_train)

# %%
pca = PCA()
X_train = pca.fit_transform(X_train)
X_test = pca.transform(X_test)

# %%
explained_variance_word = pca.explained_variance_ratio_
explained_variance_word
# Out:
# array([4.94539821e-01, 1.58272921e-01, 9.43105910e-02, 8.86927646e-02,
#        7.06072673e-02, 4.14333486e-02, 3.01392688e-02, 1.65662627e-02,
#        5.14795603e-03, 2.35541516e-04, 5.42575078e-05])

# %%
fig1 = plt.figure(figsize=(35,15))
# fig1.figure(figsize=(20,30))

ax1 = fig1.add_subplot(111)

# week_22.plot.line(x="topic_75", y="count",
ax1.set_title('Explained Variance Ratio from Topic Modeling Diagnostic Metrics ', fontsize=14, fontweight="bold")
ax1.set_xlabel("Number of Topics", fontsize=12)
ax1.set_ylabel("Doc_Count", fontsize=12)
ax1.plot(df_cols[1:10], explained_variance, label="Overall Topic Diagnostics")
ax1.plot(df_cols[10:21], explained_variance_word, label="Detail Word Diagnostics")


ax1.set_xlabel('Diagnostic Metrics')
ax1.set_ylabel('Variance')
ax1.set_title('Diagnostic Metric Comparision')

# ax1.figure(figsize=(20,30))

plt.legend(loc="upper left")
fig1.savefig('Topic percentage over May 2020 Tweets relating to COVID-19.png')

# %% [markdown]
# # Sentiment Analysis (VADER) - Overall Distribution

# %%
tweets_topic_distribution_df = pd.read_pickle("/Users/austingerner/Documents/gw/capstone/modeling/lda/data/tweet_topic_distribution_location.pkl")

# %%
tweets_topic_distribution_df.head()
# Out:
#     city country county                      created_at                   id  \
# 0                        Mon May 11 23:15:56 +0000 2020  1259985620681850881
# 1                        Thu May 14 03:05:59 +0000 2020  1260768292265852928
# 2                        Sun May 10 18:17:34 +0000 2020  1259548147971391489
# 3  Delhi   India   Rewa  Tue May 12 08:07:10 +0000 2020  1260119310913200129
# 4                        Sun May 31 23:32:27 +0000 2020  1267237537090854914
#
#   lang latitude longitude                                     no_stop_joined  \
# 0   en                     another like tits cock cumtribute nude naked a...
# 1   en                     going start mass deportation essential worker ...
# 2   en                           devilish illness covid bounder borisjohnson
# 3   en  24.7338   81.3346  record deaths reported covid death toll delhi ...
# 4   en                      latest books data profit daily thanks covid news
#
# ...

# %%
tweets_topic_distribution_sentiment_df = tweets_topic_distribution_df[['id', 'tidy_tweet', 'tokens_no_stop', 'topic_75']].copy()

# %%
tweets_topic_distribution_sentiment_df.shape
# Out:
# (3617474, 4)

# %%
vader_analyzer = SentimentIntensityAnalyzer()
negative = []
neutral = []
positive = []
compound = []
def sentiment_scores(df, negative, neutral, positive, compound):
    for i in df['tidy_tweet']:
        sentiment_dict = vader_analyzer.polarity_scores(i)
        negative.append(sentiment_dict['neg'])
        neutral.append(sentiment_dict['neu'])
        positive.append(sentiment_dict['pos'])
        compound.append(sentiment_dict['compound'])
# Function calling 
sentiment_scores(tweets_topic_distribution_sentiment_df, negative, neutral, positive, compound)
# Prepare columns to add the scores later
tweets_topic_distribution_sentiment_df["negative"] = negative
tweets_topic_distribution_sentiment_df["neutral"] = neutral
tweets_topic_distribution_sentiment_df["positive"] = positive
tweets_topic_distribution_sentiment_df["compound"] = compound
# Fill the overall sentiment with encoding:
# (-1)Negative, (0)Neutral, (1)Positive
sentiment = []
for i in tweets_topic_distribution_sentiment_df['compound']:
    if i >= 0.05 : 
        sentiment.append(1)
  
    elif i <= - 0.05 : 
        sentiment.append(-1) 
        
    else : 
        sentiment.append(0)
tweets_topic_distribution_sentiment_df['sentiment'] = sentiment

# %%
tweets_topic_distribution_sentiment_df.head(50)
# Out:
#                      id                                         tidy_tweet  \
# 0   1259985620681850881  here another like #tits #cock #cumtribute #nud...
# 1   1260768292265852928  when going start mass deportation your essenti...
# 2   1259548147971391489      devilish illness #covid bounder #borisjohnson
# 3   1260119310913200129  with record more deaths reported #covid death ...
# 4   1267237537090854914  latest books data profit daily thanks #covid #...
# 5   1260629898210803712  only #redwave happening counting dead american...
# 6   1258533154257686528  girl about different ways rolling that each me...
# 7   1257602651228905473  possible second wave coronavirus tune savannah...
# 8   1260110181410758657  bhubaneswar municipal corporation #bmc seals b...
# 9   1259002047497527297  convolutional neural network diagnose covid fr...
# 10  1259414131033157638  latest healthcare industry daily thanks #covid...
# ...

# %%
# Draw Plot
fig, ax = plt.subplots(figsize=(10, 6), subplot_kw=dict(aspect="equal"), dpi= 80)

data = [tweets_topic_distribution_sentiment_df.sentiment.value_counts()[-1], tweets_topic_distribution_sentiment_df.sentiment.value_counts()[0], tweets_topic_distribution_sentiment_df.sentiment.value_counts()[1]]
categories = ['Negative', 'Neutral', 'Positive']
explode = [0.05,0.05,0.05]

def func(pct, allvals):
    absolute = int(pct/100.*np.sum(allvals))
    return "{:.1f}% ({:d} )".format(pct, absolute)

wedges, texts, autotexts = ax.pie(data, 
                                  autopct=lambda pct: func(pct, data),
                                  textprops=dict(color="w"), 
                                  colors=['#e55039', '#3c6382', '#78e08f'],
                                  startangle=140,
                                  explode=explode)

# Decoration
ax.legend(wedges, categories, title="Sentiment", loc="center left", bbox_to_anchor=(1, 0.2, 0.5, 1))
plt.setp(autotexts, size=10, weight=700)
ax.set_title("Number of Tweets by Sentiment", fontsize=12, fontweight="bold")
plt.show()

# %%
labels = ['Negative', 'Neutral', 'Positive']
freq = [tweets_topic_distribution_sentiment_df.sentiment.value_counts()[-1], tweets_topic_distribution_sentiment_df.sentiment.value_counts()[0], tweets_topic_distribution_sentiment_df.sentiment.value_counts()[1]]
index = np.arange(len(freq))

plt.figure(figsize=(8,6))
plt.bar(index, freq, alpha=0.8, color= 'black')
plt.xlabel('Sentiment', fontsize=13)
plt.ylabel('Number of Tweets', fontsize=11)
plt.xticks(index, labels, fontsize=11, fontweight="bold") 
plt.title('Number of Tweets per Sentiment', fontsize=12, fontweight="bold")
plt.ylim(0, len(tweets_topic_distribution_sentiment_df['tidy_tweet']))
plt.show()

# %%
data = tweets_topic_distribution_sentiment_df[(tweets_topic_distribution_sentiment_df["sentiment"]!=0)]

# %%
plt.figure(figsize=(8,6), dpi= 80)
seaborn.kdeplot(data["compound"], shade=True, color="#3c6382", label="Overall Compound Score", alpha=.7)

# Decoration
plt.title('Density Plot of Overall Compound Score', fontsize=11, fontweight='bold')
plt.axvline(x=0, color='#e55039')
plt.legend()
plt.show()

# %%
def lemmatization(tweets, allowed_postags=['NOUN', 'ADJ', 'VERB', 'ADV']):
    """https://spacy.io/api/annotation"""
    tweets_out = []
    for sent in tweets:
        doc = nlp(" ".join(sent)) 
        tweets_out.append([token.lemma_ for token in doc if token.pos_ in allowed_postags])
    return tweets_out

# %%
nlp = spacy.load('en', disable=['parser', 'ner'])

# %%
tweets_topic_distribution_sentiment_df['lemmatized'] = lemmatization(tweets_topic_distribution_sentiment_df['tokens_no_stop'], allowed_postags=['NOUN', 'ADJ', 'VERB', 'ADV'])

# %%
df_pos = tweets_topic_distribution_sentiment_df[tweets_topic_distribution_sentiment_df['sentiment']==1]
df_neg = tweets_topic_distribution_sentiment_df[tweets_topic_distribution_sentiment_df['sentiment']==(-1)]

# %%
# Join the tweet back together
def rejoin_words(row):
    words = row['lemmatized']
    joined_words = (" ".join(words))
    return joined_words

# %%
all_words_pos = ' '.join([text for text in df_pos.apply(rejoin_words, axis=1)])
all_words_neg = ' '.join([text for text in df_neg.apply(rejoin_words, axis=1)])

# %%
wordcloud = WordCloud(width=900, height=600, random_state=21, max_font_size=110, background_color='white', 
                      max_words=200,colormap='summer').generate(all_words_pos)

plt.figure(figsize=(12, 8))
plt.title('WordCloud of Positive Tweets', fontsize=14, fontweight="bold")
plt.imshow(wordcloud, interpolation="bilinear")
plt.axis('off')
plt.show()

# %%
wordcloud = WordCloud(width=900, height=600, random_state=21, max_font_size=110, background_color='ghostwhite', 
                      max_words=200,colormap='autumn').generate(all_words_neg)

plt.figure(figsize=(12, 8))
plt.title('WordCloud of Negative Tweets', fontsize=14, fontweight="bold")
plt.imshow(wordcloud, interpolation="bilinear")
plt.axis('off')
plt.show()

# %%
x1 = df_pos['compound']
x2 = df_neg['compound']
plt.figure(figsize=(15,6))
plt.suptitle('Compound Score Distribution', fontsize=14, fontweight="bold")
plt.subplot(1,2,1)

seaborn.distplot(x1, color="g", bins=15, hist_kws={"alpha": 0.5,"rwidth":0.8})
plt.title('Positive Tweets',fontsize=12, fontweight="bold")
plt.xlabel("Compound Score", fontsize=12)
plt.xlim([0,1])

# Chart 2: Derivative Function
plt.subplot(1,2,2)
seaborn.distplot(x2, color="r", bins=15, hist_kws={"alpha": 0.5, "rwidth":0.8})
plt.title("Negative Tweets",fontsize=12, fontweight="bold")
plt.xlabel("Compound Score", fontsize=12)
plt.xlim([-1,0])

plt.show()
# Out:
# /Applications/anaconda3/lib/python3.8/site-packages/seaborn/distributions.py:2551: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# /Applications/anaconda3/lib/python3.8/site-packages/seaborn/distributions.py:2551: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)

# %%
x1.describe()
# Out:
# count    1.457502e+06
# mean     4.646044e-01
# std      2.025670e-01
# min      5.000000e-02
# 25%      3.182000e-01
# 50%      4.404000e-01
# 75%      6.124000e-01
# max      9.854000e-01
# Name: compound, dtype: float64

# %%
x2.describe()
# Out:
# count    833915.000000
# mean         -0.445687
# std           0.211660
# min          -0.996500
# 25%          -0.599400
# 50%          -0.440400
# 75%          -0.296000
# max          -0.050000
# Name: compound, dtype: float64

# %%
# data_to_plot = [x1,(x2)*-1]
# # Box-plot
# fig = plt.figure(1, figsize=(8, 6))
# ax = fig.add_subplot(111)
# bp = ax.boxplot(data_to_plot, patch_artist=True)
# for box in bp['boxes']:
#     change outline color
#     box.set( color='#b2bec3', linewidth=2)
# ## change color and linewidth of the whiskers
# for whisker in bp['whiskers']:
#     whisker.set(color='#7570b3', linewidth=2)
# for median in bp['medians']:
#     median.set(color='#e17055', linewidth=3)
# plt.boxplot(data_to_plot)
# plt.title('Compound Score', fontsize=13, fontweight='bold')
# ax.set_xticklabels(['Positive', 'Negative (inverse sign)'], fontweight='bold')
# plt.show()

# %%
df_pos.sort_values('compound', inplace=True, ascending=False)
df_pos.reset_index(drop=True, inplace=True)
# Out:
# <ipython-input-45-3bfd5e3767e3>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_pos.sort_values('compound', inplace=True, ascending=False)

# %%
df_pos.head(10)
# Out:
#                     id                                         tidy_tweet  \
# 0  1257814560251076609  #volunteer #coronavirus test this week love lo...
# 1  1256227844365131782  hope love pray love wish love dream love your ...
# 2  1259326042302369792  celebrating first true love love pure love tru...
# 3  1264663857055830016  dear friends want wish your family very happy ...
# 4  1264123398457896960  take caring love behavior never this kind love...
# 5  1259077110582226944  laugh laugh laugh smile smile smile everyone e...
# 6  1264981163275423744  happy birthday hope have wonderful filled with...
# 7  1264981275590438912  happy birthday hope have wonderful filled with...
# 8  1258345827388407808  health greatest gift contentment greatest weal...
# 9  1258271888423321600  health greatest gift contentment greatest weal...
#
#                                       tokens_no_stop  topic_75  negative  \
# 0  [volunteer, coronavirus, test, week, love, lov...        54       0.0
# ...

# %%
# 10 Most Negative Tweets
df_neg.sort_values('compound', inplace=True)
df_neg.reset_index(drop=True).head(15)
# Out:
# <ipython-input-47-ede40f2716ea>:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_neg.sort_values('compound', inplace=True)
#                      id                                         tidy_tweet  \
# 0   1258370732201050112  fake fake fake fake fake fake fake fake fake f...
# 1   1258371018101526529  fake fake fake fake fake fake fake fake fake f...
# 2   1258371689324392449  fake fake fake fake fake fake fake fake fake f...
# 3   1258371367432589312  fake fake fake fake fake fake fake fake fake f...
# 4   1258371203196227592  fake fake fake fake fake fake fake fake fake f...
# 5   1258371922838028288  fake fake fake fake fake fake fake fake fake f...
# 6   1260728836116942848  #coronavirus fear fear fear fear fear fear fea...
# ...

# %%
df_neg.head(10)
# Out:
#                           id  \
# 914696   1258370732201050112
# 331247   1258371018101526529
# 1975086  1258371689324392449
# 647010   1258371367432589312
# 462159   1258371203196227592
# 1418312  1258371922838028288
# 3608047  1260728836116942848
# 143270   1262397070536835072
# 981081   1260185965932363776
# 1717804  1261174410381340673
#
#                                                 tidy_tweet  \
# 914696   fake fake fake fake fake fake fake fake fake f...
# 331247   fake fake fake fake fake fake fake fake fake f...
# 1975086  fake fake fake fake fake fake fake fake fake f...
# 647010   fake fake fake fake fake fake fake fake fake f...
# 462159   fake fake fake fake fake fake fake fake fake f...
# 1418312  fake fake fake fake fake fake fake fake fake f...
# 3608047  #coronavirus fear fear fear fear fear fear fea...
# 143270   fake fake fake fake fake fuck fake fake fake f...
# 981081   fuck fuck china fuck fuck china fuck fuck chin...
# ...

# %%
tweets_topic_distribution_sentiment_df.to_pickle('sentiment_analysis_vader_results_may_2020.pkl')
